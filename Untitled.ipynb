# %% [markdown]
# # Predicting which of the Employee will Quit the Company.

# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv(r"C:\Users\Asus\Desktop\project1\Project of machine learning\Employee leaving\hr_data.csv")

# %%
df
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
# ...

# %% [markdown]
# # Exploring the dataset

# %%
df.shape
# Out:
# (14999, 9)

# %%
df.size
# Out:
# 134991

# %%
df.columns
# Out:
# Index(['employee_id', 'number_project', 'average_montly_hours',
#        'time_spend_company', 'Work_accident', 'left', 'promotion_last_5years',
#        'department', 'salary'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 9 columns):
# employee_id              14999 non-null int64
# number_project           14999 non-null int64
# average_montly_hours     14999 non-null int64
# time_spend_company       14999 non-null int64
# Work_accident            14999 non-null int64
# left                     14999 non-null int64
# promotion_last_5years    14999 non-null int64
# department               14999 non-null object
# salary                   14999 non-null object
# dtypes: int64(7), object(2)
# memory usage: 1.0+ MB

# %%
df['department'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
df['salary'].unique()
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %% [markdown]
# ### loading another csv file( Employee satisfaction)

# %%
s_df= pd.read_excel(r"C:\Users\Asus\Desktop\project1\Project of machine learning\Employee leaving\s_data.xlsx")

# %%
s_df
# Out:
#        EMPLOYEE #  satisfaction_level  last_evaluation
# 0            1003                0.38             0.53
# 1            1005                0.80             0.86
# 2            1486                0.11             0.88
# 3            1038                0.72             0.87
# 4            1057                0.37             0.52
# ...           ...                 ...              ...
# 14994       87670                0.40             0.57
# 14995       87673                0.37             0.48
# 14996       87679                0.37             0.53
# 14997       87681                0.11             0.96
# 14998       87684                0.37             0.52
#
# [14999 rows x 3 columns]

# %%
s_df.size
# Out:
# 44997

# %%
s_df.shape
# Out:
# (14999, 3)

# %%
s_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 3 columns):
# EMPLOYEE #            14999 non-null int64
# satisfaction_level    14972 non-null float64
# last_evaluation       14972 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 351.7 KB

# %%
# merging empolyee_id column with s_df
final_df= df.set_index("employee_id").join(s_df.set_index('EMPLOYEE #'))

# %%
final_df
# Out:
#              number_project  average_montly_hours  time_spend_company  \
# employee_id
# 1003                      2                   157                   3
# 1005                      5                   262                   6
# 1486                      7                   272                   4
# 1038                      5                   223                   5
# 1057                      2                   159                   3
# ...                     ...                   ...                 ...
# 87670                     2                   151                   3
# 87673                     2                   160                   3
# 87679                     2                   143                   3
# 87681                     6                   280                   4
# 87684                     2                   158                   3
#
#              Work_accident  left  promotion_last_5years department  salary  \
# employee_id
# ...

# %%
final_df= final_df.reset_index()

# %%
final_df
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
# ...

# %%
final_df[final_df.isnull().any(axis=1)]
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 18            3794               2                   160                   3
# 19            1140               5                   262                   5
# 33            1230               2                   140                   3
# 53            1340               2                   132                   3
# 72           22316               2                   149                   3
# 92            1581               2                   143                   3
# 107          17376               2                   148                   3
# 120           1739               4                   158                   4
# 137           1847               2                   129                   3
# 175          32923               4                   164                   2
# 191           2160               4                   226                   6
# ...

# %%
final_df.describe()
# Out:
#         employee_id  number_project  average_montly_hours  time_spend_company  \
# count  14999.000000    14999.000000          14999.000000        14999.000000
# mean   45424.627575        3.803054            201.050337            3.498233
# std    25915.900127        1.232592             49.943099            1.460136
# min     1003.000000        2.000000             96.000000            2.000000
# 25%    22872.500000        3.000000            156.000000            3.000000
# 50%    45448.000000        4.000000            200.000000            3.000000
# 75%    67480.500000        5.000000            245.000000            4.000000
# max    99815.000000        7.000000            310.000000           10.000000
#
#        Work_accident          left  promotion_last_5years  satisfaction_level  \
# count   14999.000000  14999.000000           14999.000000        14972.000000
# mean        0.144610      0.238083               0.021268            0.612830
# ...

# %%
# Replacing all the null value with the mean of satisfaction
final_df.fillna(final_df.mean(),inplace=True)

# %%
# Checking if we have any null value left
final_df[final_df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [employee_id, number_project, average_montly_hours, time_spend_company, Work_accident, left, promotion_last_5years, department, salary, satisfaction_level, last_evaluation]
# Index: []

# %%
final_df
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
# ...

# %%
final_df['department'].value_counts()
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: department, dtype: int64

# %%
final_df.groupby('department').mean()
# Out:
#               employee_id  number_project  average_montly_hours  \
# department
# IT           45920.887531        3.816626            202.215974
# RandD        41865.524778        3.853875            200.800508
# accounting   44946.953064        3.825293            201.162973
# hr           42848.071719        3.654939            198.684709
# management   53328.726984        3.860317            201.249206
# marketing    47454.285548        3.687646            199.385781
# product_mng  48799.177384        3.807095            199.965632
# sales        46394.321256        3.776329            200.911353
# support      43909.381337        3.803948            200.758188
# technical    43241.036765        3.877941            202.497426
#
#              time_spend_company  Work_accident      left  \
# department
# IT                     3.468623       0.133659  0.222494
# RandD                  3.367217       0.170267  0.153748
# accounting             3.522816       0.125163  0.265971
# ...

# %%
final_df.groupby('department').sum()
# Out:
#              employee_id  number_project  average_montly_hours  \
# department
# IT              56344929            4683                248119
# RandD           32948168            3033                158030
# accounting      34474313            2934                154292
# hr              31664725            2701                146828
# management      33597098            2432                126787
# marketing       40715777            3164                171073
# product_mng     44016858            3434                180369
# sales          192072490           15634                831773
# support         97874011            8479                447490
# technical      117615620           10548                550793
#
#              time_spend_company  Work_accident  left  promotion_last_5years  \
# department
# IT                         4256            164   273                      3
# RandD                      2650            134   121                     27
# ...

# %% [markdown]
# ## Data visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,10))
sns.heatmap(final_df.corr(), annot=True, cmap='terrain')

# %%
sns.pairplot(data=final_df, hue='left')
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\Asus\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
sns.barplot(x='left',y='satisfaction_level', data=final_df)

# %%
sns.barplot(x='promotion_last_5years', y='satisfaction_level', hue='left', data= final_df)

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()
k= le.fit_transform(final_df['salary'])

# %%
k
# Out:
# array([1, 2, 2, ..., 1, 1, 1])

# %%
final_df['salary_num']=k

# %%
final_df
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
# ...

# %%
final_df.drop(['salary'], axis=1, inplace=True)

# %%
final_df
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
# ...

# %%
l= le.fit_transform(final_df['department'])

# %%
l
# Out:
# array([7, 7, 7, ..., 8, 8, 8])

# %%
final_df['department_num']=l

# %%
final_df
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
# ...

# %%
final_df.drop(['department'], axis=1, inplace=True)

# %%
final_df
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
# ...

# %%
x=final_df.drop(['left'], axis=1)

# %%
x
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
# ...

# %%
y=final_df['left']

# %%
y.value_counts()
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3)

# %%
x_train
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 3751         84562               4                   169                   4
# 2722         12782               5                   218                   4
# 12449        55748               5                   239                   5
# 7780         45994               4                   138                   2
# 14863        86976               6                   290                   4
# ...            ...             ...                   ...                 ...
# 2530         15199               2                   275                   2
# 6186         36467               4                   160                   3
# 3730         79364               3                   101                   2
# 9588         56612               3                   256                   3
# 13092        76332               5                   137                   3
#
# ...

# %%
print("x_train: ", x_train.size)
print("x_test: ", x_test.size)
print("y_train: ", y_train.size)
print("y_test: ", y_test.size)
# Out:
# x_train:  104990
# x_test:  45000
# y_train:  10499
# y_test:  4500

# %%
from sklearn.metrics import accuracy_score

# %%
#Decision Tree 
from sklearn.tree import DecisionTreeClassifier
dc= DecisionTreeClassifier()
dc.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
prediction_dc= dc.predict(x_test)

# %%
prediction_dc.size
# Out:
# 4500

# %%
accuracy_score(y_test, prediction_dc)
# Out:
# 0.9711111111111111

# %%
final_df.drop(['employee_id'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-cd57762b1a63> in <module>
# ----> 1 final_df.drop(['employee_id'], axis=1, inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
final_df
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years  satisfaction_level  \
# 0                  0     1                      0                0.38
# ...

# %%
category= ['Employee will leave', 'Employee will stay']

# %%
custom_dc= [[5,300,10,5,0,1,0.90,0.77,2,8]]

# %%
category[int(dc.predict(custom_dc))]
# Out:
# 'Employee will stay'
